# %%
#Regression model all features
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, roc_auc_score

df = pd.read_csv('breastcancer_prep_csv')

#Split data into training and test
X = df[['Cl.thickness', 'Cell.size', 'Cell.shape', 'Marg.adhesion', 'Epith.c.size', 'Bare.nuclei', 'Bl.cromatin', 'Normal.nucleoli', 'Mitoses']]
y = df['Class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#Set model
model = LogisticRegression(random_state=42)

#Train model
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

#Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Logistic Regression Accuracy: {accuracy}")

# Calculate classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Calculate ROC-AUC score
roc_auc = roc_auc_score(y_test, model.predict_proba(X_test)[:, 1])
print(f"ROC-AUC Score: {roc_auc}")

# Get feature coefficients
coefficients = model.coef_[0]

# Map coefficients to feature names
feature_importance = pd.DataFrame({'Feature': X_train.columns, 'Coefficient': coefficients})
feature_importance = feature_importance.sort_values(by='Coefficient', ascending=False)

# Print feature importance
print("Feature Importance:")
print(feature_importance)
# Out:
# Logistic Regression Accuracy: 0.9463414634146341
# Classification Report:
#               precision    recall  f1-score   support
#
#       benign       0.93      0.98      0.96       127
#    malignant       0.97      0.88      0.93        78
#
#     accuracy                           0.95       205
#    macro avg       0.95      0.93      0.94       205
# weighted avg       0.95      0.95      0.95       205
#
# ROC-AUC Score: 0.9963658388855239
# Feature Importance:
#            Feature  Coefficient
# 5      Bare.nuclei     2.882900
# 0     Cl.thickness     2.156151
# 2       Cell.shape     1.799256
# 6      Bl.cromatin     1.772363
# 1        Cell.size     1.433520
# 3    Marg.adhesion     1.375465
# 7  Normal.nucleoli     1.303062
# 8          Mitoses     0.957151
# 4     Epith.c.size     0.597569

# %%
#Decision tree model all features
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, roc_auc_score

df = pd.read_csv('breastcancer_prep_csv')

#Split data into training and test
X = df[['Cl.thickness', 'Cell.size', 'Cell.shape', 'Marg.adhesion', 'Epith.c.size', 'Bare.nuclei', 'Bl.cromatin', 'Normal.nucleoli', 'Mitoses']]
y = df['Class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

#Set model
model = DecisionTreeClassifier(max_depth=8, random_state=42)

#Train model
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

#Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Decision tree Accuracy: {accuracy}")

# Calculate classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Calculate ROC-AUC score
roc_auc = roc_auc_score(y_test, model.predict_proba(X_test)[:, 1])
print(f"ROC-AUC Score: {roc_auc}")

importances = model.feature_importances_

# Map importances to feature names
feature_importance = pd.DataFrame({'Feature': X_train.columns, 'Importance': importances})
feature_importance = feature_importance.sort_values(by='Importance', ascending=False)

# Print feature importance
print("Feature Importance:")
print(feature_importance)


print(model.score(X_train,y_train))
# Out:
# Decision tree Accuracy: 0.9463414634146341
# Classification Report:
#               precision    recall  f1-score   support
#
#       benign       0.95      0.97      0.96       127
#    malignant       0.95      0.91      0.93        78
#
#     accuracy                           0.95       205
#    macro avg       0.95      0.94      0.94       205
# weighted avg       0.95      0.95      0.95       205
#
# ROC-AUC Score: 0.9393801736321422
# Feature Importance:
#            Feature  Importance
# 1        Cell.size    0.745449
# 5      Bare.nuclei    0.132499
# 6      Bl.cromatin    0.025902
# 3    Marg.adhesion    0.023472
# 7  Normal.nucleoli    0.022421
# 4     Epith.c.size    0.019757
# 0     Cl.thickness    0.019716
# 2       Cell.shape    0.008331
# 8          Mitoses    0.002453
# 1.0

# %%
#Nearest neighbor model all features
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, roc_auc_score
import seaborn as sns

df = pd.read_csv('breastcancer_prep_csv')

#Split data into training and test
X = df[['Cl.thickness', 'Cell.size', 'Cell.shape', 'Marg.adhesion', 'Epith.c.size', 'Bare.nuclei', 'Bl.cromatin', 'Normal.nucleoli', 'Mitoses']]
y = df['Class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = KNeighborsClassifier(n_neighbors=22)

model.fit(X_train, y_train)

#Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Decision tree Accuracy: {accuracy}")

# Calculate classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Calculate ROC-AUC score
roc_auc = roc_auc_score(y_test, model.predict_proba(X_test)[:, 1])
print(f"ROC-AUC Score: {roc_auc}")


# Map importances to feature names
#Check for feature importance the data analysis pairplot to find features that have a high coallation. Below is the pairplot for ease of use but for more data see the data analysis report.

sns.pairplot(df)
# Out:
# Decision tree Accuracy: 0.9463414634146341
# Classification Report:
#               precision    recall  f1-score   support
#
#       benign       0.93      0.98      0.96       127
#    malignant       0.97      0.88      0.93        78
#
#     accuracy                           0.95       205
#    macro avg       0.95      0.93      0.94       205
# weighted avg       0.95      0.95      0.95       205
#
# ROC-AUC Score: 0.9943468604885928
